# %% [markdown]
# <a href="https://www.kaggle.com/code/teetlhmus/pjk-10-klass-spektogramm?scriptVersionId=128325561" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # helifaile (wav) käsitletakse Pyhtonis numpy array'dena
import pandas as pd # DataFrame's, csv faili sisselugemine

# %%
# Lisame notebook'ile andmed: Piano Triads Wavset

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# Out:
# /kaggle/input/play-audio-read-the-files-create-a-spectrogram/new_slice.wav
# /kaggle/input/play-audio-read-the-files-create-a-spectrogram/__results__.html
# /kaggle/input/play-audio-read-the-files-create-a-spectrogram/__output__.json
# /kaggle/input/play-audio-read-the-files-create-a-spectrogram/custom.css
# /kaggle/input/play-audio-read-the-files-create-a-spectrogram/__results___files/__results___31_0.png
# /kaggle/input/piano-triads-wavset/triads.csv
# /kaggle/input/piano-triads-wavset/piano_triads/E_maj_7_1.wav
# /kaggle/input/piano-triads-wavset/piano_triads/C_maj_2_1.wav
# /kaggle/input/piano-triads-wavset/piano_triads/Cs_maj_4_0.wav
# /kaggle/input/piano-triads-wavset/piano_triads/Fs_dim_7_1.wav
# /kaggle/input/piano-triads-wavset/piano_triads/Eb_maj_7_0.wav
# /kaggle/input/piano-triads-wavset/piano_triads/B_maj_7_0.wav
# /kaggle/input/piano-triads-wavset/piano_triads/E_maj_6_0.wav
# /kaggle/input/piano-triads-wavset/piano_triads/A_maj_6_1.wav
# ...

# %%
# kuvab "../input" kaustas olevate alamkaustade nimed
os.listdir('../input')
# Out:
# ['play-audio-read-the-files-create-a-spectrogram', 'piano-triads-wavset']

# %%
# kolmkõlade kirjeldused
list_of_sounds = pd.read_csv("/kaggle/input/piano-triads-wavset/triads.csv")

# %%
# dataframe'i andmete kirjeldus:
list_of_sounds.describe
# Out:
# <bound method NDFrame.describe of          Chord Note1 Note2 Note3
# 0    C_maj_2_0   C_2   E_2   G_2
# 1    C_maj_3_0   C_3   E_3   G_3
# 2    C_maj_4_0   C_4   E_4   G_4
# 3    C_maj_5_0   C_5   E_5   G_5
# 4    C_maj_6_0   C_6   E_6   G_6
# ..         ...   ...   ...   ...
# 355  B_min_3_1   B_4   D_4  Fs_4
# 356  B_min_4_1   B_5   D_5  Fs_5
# 357  B_min_5_1   B_6   D_6  Fs_6
# 358  B_min_6_1   B_7   D_7  Fs_7
# 359  B_min_7_1   B_8   D_8  Fs_8
#
# [360 rows x 4 columns]>

# %%
import IPython.display as ipd  # To play sound in the notebook

faili_nimi = '/kaggle/input/piano-triads-wavset/piano_triads/Bb_dim_7_0.wav'
# fname = '../input/piano-triads-wavset/piano_triads/C_maj_5_0.wav'   # Hi-hat
# fname = '../input/piano-triads-wavset/piano_triads/F_dim_7_1.wav'

ipd.Audio(faili_nimi)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
# kasutame scipy funktsioone
from scipy.io import wavfile
rate, data = wavfile.read(faili_nimi)
print("Sampling (frame) rate = ", rate)
print("Total samples (frames) = ", data.shape)
print("Duration in seconds = ", np.count_nonzero(data) / rate)
#print(data)
# Out:
# Sampling (frame) rate =  44100
# Total samples (frames) =  (132300,)
# Duration in seconds =  3.0

# %%
# kolmkõla amplituud samplite kaupa
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data)

# %%
# "zoom-in": graafik esimese 20.000 sample'i kohta (u. 0,45 sekundit helifaili algusest)
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[:20000], '-') # proovi asendada "-" näiteks "." või "*"-ga

# %%
# "zoom-in": graafik esimese 2500 sample'i kohta
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[:2500], '.');plt.plot(data[:2500], '-');

# %%
# "zoom-in": graafik sample'ite 500 kuni 700 kohta
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[500:700], '.');plt.plot(data[500:700], '-');

# %%
import os
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

data, rate = librosa.load(faili_nimi, sr=44100)

print("Sampling (frame) rate = ", rate)
print("Total samples (frames) = ", data.shape)
print("Duration in seconds = ", np.count_nonzero(data) / rate)
# print(data)
# Out:
# Sampling (frame) rate =  44100
# Total samples (frames) =  (132300,)
# Duration in seconds =  3.0

# %%
# kolmkõla amplituud samplite kaupa
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data)

# %%
# "zoom-in": graafik esimese 20.000 sample'i kohta (u. 0,45 sekundit helifaili algusest)
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[:20000], '-') # proovi asendada "-" näiteks "." või "*"-ga

# %%
# "zoom-in": graafik esimese 2500 sample'i kohta
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[:2500], '.');plt.plot(data[:2500], '-');

# %%
# "zoom-in": graafik sample'ite 500 kuni 700 kohta
plt.figure(figsize=(16, 4))
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.plot(data[500:700], '.');plt.plot(data[500:700], '-');

# %%
# Fourier teisendus, tulemus omistatakse muutujale x
x = librosa.stft(data)

# Teisendab amplituudi põhise spektogrammi dB põhiseks
db = librosa.amplitude_to_db(abs(x)) # kasutame amplituudi absoluutväärtust

# %%
# Graafiku joonistamine
plt.figure(figsize=(14, 5))
librosa.display.specshow(db, sr=rate, x_axis='time', y_axis='hz')
plt.colorbar() # lisab dB legendi paremale poole

# %%
# "Zoom-in" - failist loetud kolmkõla sagedused paistavad olema piirkonnas 0 .. 4000 Hz
plt.figure(figsize=(14, 5))
librosa.display.specshow(db, sr=rate, x_axis='time', y_axis='hz')
plt.ylim([0, 4000]) # piirame graafikul näidatavat sagedusvahemikku
plt.colorbar()

# Selgemalt eristuvad 3 sagedust, ülejäänu on müra

# %%
# lõikame ära helilõigu alguse ja lõpu: järele jääb lõik alates 0.25 sek kuni 1.5 sek
alamosa = data[11025:66150] # 11025 = 44100 / 4; 55150 = 44100 * 1.5

# Fourier teisendus, tulemus omistatakse muutujale x
x_alam = librosa.stft(alamosa)

# Teisendab amplituudi põhise spektogrammi dB põhiseks
db_alam = librosa.amplitude_to_db(abs(x_alam)) # kasutame amplituudi absoluutväärtust

# %%
# Uus graafik alamlõigust
plt.figure(figsize=(14, 5))
librosa.display.specshow(db_alam, sr=rate, x_axis='time', y_axis='hz')
plt.ylim([0, 4000]) # piirame graafikul näidatavat sagedusvahemikku
plt.colorbar()

# %%
# proovi millised sagedused esinevad teistes kolmkõlades
